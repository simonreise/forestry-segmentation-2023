# %% [markdown]
# # <div style="text-align: right;font-family:Times New Roman">Приложение Б-1</div>
# # <div style="text-align: center;font-family:Times New Roman">Предобработка снимков Sentinel-2</div>

# %% [markdown]
# # Preprocessing of Sentinel-2 imagery
# # Предобработка снимков Sentinel-2
# ---
# In this notebook Sentinel-2 imagery is being preprocessed. Preprocessing includes atmospheric correction using Sen2Cor algorythm, applying superresolution algorythm to 20- and 60-meters bands, cloud masking, reprojecting and mosaic creation.
#
# В этом блокноте выполняется предобработка снимков Sentinel-2. Предобработка включает в себя атмосферную коррекцию с применением алгоритма Sen2Cor, применение алгоритма суперразрешения к каналам с разрешением 20 и 60 м, маскировка облаков, перепроецирование и создание мозаики.

# %% [markdown]
# ### Importing dependencies
# ### Импорт необходимых библиотек

# %%
import os
import subprocess
import shutil
import random
import re
from typing import List, Tuple
from collections import defaultdict
from pathlib import Path
import numpy as np
from glob import glob
import geopandas as gpd
from osgeo import gdal
import rasterio as rio
from rasterio.warp import calculate_default_transform, reproject, Resampling
import rasterio.merge
import rasterio.fill
from rasterio.io import MemoryFile
from rasterio.enums import Resampling
from rasterio.windows import Window
from rasterio.transform import Affine
import fiona
import shapely
from shapely.geometry import box
import zipfile

# %% [markdown]
# ### Unzipping all archives with images
# ### Распаковка всех архивов со снимками

# %%
#path to archives / путь к архивам
zippath = 'E:\\Work\\Sentinel\\'
archives = glob(zippath+'*')
#where to unpack / конечный путь распаковки
wpath = 'F:\\Work\\CorrProizv\\LVL1\\'
for archive in archives:
    with zipfile.ZipFile(archive, 'r') as zip_ref:
        zip_ref.extractall(wpath)

# %% [markdown]
# ### Applying [Sen2Cor](https://step.esa.int/main/snap-supported-plugins/sen2cor/) atmospheric correction algorythm
# ### Применение алгоритма атмосферной коррекции [Sen2Cor](https://step.esa.int/main/snap-supported-plugins/sen2cor/)

# %%
#importing data / импорт данных
wpath = 'F:\\Work\\CorrProizv\\Imagery\\'
paths = glob(wpath+'*')
paths
# Out:
# ['F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20170731T060631_N9999_R134_T44VMN_20210915T184413.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20170731T060631_N9999_R134_T44VNQ_20210916T052032.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20170731T060631_N9999_R134_T44VPQ_20210915T081105.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20180630T072621_N9999_R049_T41VML_20210916T045925.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20180723T055641_N9999_R091_T44VNP_20210915T192826.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20180826T071621_N9999_R006_T41VMK_20210915T093843.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190701T060641_N9999_R134_T44VMN_20210915T070556.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190701T060641_N9999_R134_T44VMR_20210915T195148.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190715T054641_N9999_R048_T44VPN_20210915T042924.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190721T060641_N9999_R134_T43VFJ_20210915T012154.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190721T060641_N9999_R134_T44VLN_20210915T182127.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190721T060641_N9999_R134_T44VLP_20210915T005950.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190721T060641_N9999_R134_T44VLQ_20210915T073007.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190721T060641_N9999_R134_T44VNQ_20210915T032204.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190721T060641_N9999_R134_T45VUK_20210915T024042.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190725T072621_N9999_R049_T40VFR_20210914T225005.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190725T072621_N9999_R049_T40WFS_20210915T003945.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190725T072621_N9999_R049_T40WFT_20210915T020246.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190725T072621_N9999_R049_T41VLL_20210914T231151.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190725T072621_N9999_R049_T41VMJ_20210916T043910.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190725T072621_N9999_R049_T41VML_20210915T014030.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190725T072621_N9999_R049_T41WMM_20210915T001800.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190725T072621_N9999_R049_T41WMN_20210915T021927.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190813T061631_N9999_R034_T43VDG_20210914T212730.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190813T061631_N9999_R034_T43VFH_20210914T220628.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190813T061631_N9999_R034_T44VLN_20210914T222817.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190813T061631_N9999_R034_T44VLP_20210914T204329.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190813T061631_N9999_R034_T44VMQ_20210914T233339.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190814T054641_N9999_R048_T44VPP_20210915T074756.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190814T054641_N9999_R048_T45VUJ_20210914T214401.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190818T070621_N9999_R106_T41VPL_20210914T174935.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190820T074611_N9999_R135_T41WMN_20210914T132020.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190821T071621_N9999_R006_T41VNJ_20210914T153753.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190821T071621_N9999_R006_T41VNL_20210914T125849.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190821T071621_N9999_R006_T41VPK_20210914T143947.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190821T071621_N9999_R006_T41WNM_20210914T141333.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2A_MSIL2A_20190821T071621_N9999_R006_T41
SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190714T070629_N9999_R106_T41VPK_20210915T030003.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190714T070629_N9999_R106_T42VUN_20210915T051743.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190714T070629_N9999_R106_T42VUP_20210915T034512.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190715T063639_N9999_R120_T43VDJ_20210915T162517.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190725T063639_N9999_R120_T43VDL_20210915T151438.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190802T055649_N9999_R091_T44VNN_20210914T235559.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190814T063629_N9999_R120_T43VCG_20210915T173546.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190814T063629_N9999_R120_T43VEK_20210914T210540.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190815T074619_N9999_R135_T40WFS_20210914T202143.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190819T072619_N9999_R049_T40VFQ_20210914T160028.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190819T072619_N9999_R049_T40WFS_20210914T181115.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190819T072619_N9999_R049_T41VLJ_20210914T150753.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190819T072619_N9999_R049_T41VLL_20210914T183122.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190819T072619_N9999_R049_T41VMJ_20210914T185302.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190819T072619_N9999_R049_T41VMK_20210914T195925.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190819T072619_N9999_R049_T41VNK_20210914T164557.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190819T072619_N9999_R049_T41WMM_20210914T193713.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190819T072619_N9999_R049_T41WMN_20210914T170532.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190820T065629_N9999_R063_T41VPH_20210914T172740.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190820T065629_N9999_R063_T42VUM_20210915T123502.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20190829T072619_N9999_R049_T40VFR_20210914T104948.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200605T065629_N9999_R063_T42VUP_20210915T112829.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200605T065629_N9999_R063_T42VUQ_20210915T060139.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200607T055639_N9999_R091_T45VUH_20210914T092151.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200607T073619_N9999_R092_T41VLK_20210914T094423.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200608T070629_N9999_R106_T41VMH_20210914T090442.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200610T060639_N9999_R134_T44VNQ_20210914T075955.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200617T055639_N9999_R091_T44VMN_20210914T121732.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200715T065629_N9999_R063_T41VPF_20210913T181456.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200715T065629_N9999_R063_T41VPG_20210913T194132.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VUL_20210913T202449.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VVP_20210913T183538.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VVQ_20210913T175303.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VWQ_20210913T200226.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VXR_20210913T185752.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200716T062629_N9999_R077_T43VCF_20210915T134227.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200716T062629_N9999_R077_T43VDF_20210913T165044.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200716T062629_N9999_R077_T43VEF_20210913T173207.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200808T063629_N9999_R120_T42VWN_20210913T105049.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200808T063629_N9999_R120_T43VDK_20210913T094611.SAFE',
#  'F:\\Work\\CorrProizv\\Imagery\\S2B_MSIL2A_20200814T065629_N9999_R063_T42VVQ_20210913T075830.SAFE']

# %%
#creating env for running Sen2Cor / создание среды для запуска Sen2Cor
my_env = os.environ.copy()
my_env['PATH'] = r'C:\ProgramData\Sen2Cor-02.09.00-win64\bin;' + r'C:\ProgramData\Sen2Cor-02.09.00-win64;' + my_env['PATH']
my_env['SEN2COR_HOME'] = r'C:\ProgramData\Sen2Cor-02.09.00-win64'
my_env['SEN2COR_BIN'] = r'C:\ProgramData\Sen2Cor-02.09.00-win64\lib\python2.7\site-packages\sen2cor'
my_env['LC_NUMERIC'] = 'C'
my_env['GDAL_DATA'] = r'C:\ProgramData\Sen2Cor-02.09.00-win64\share\gdal'
my_env['GDAL_DRIVER_PATH']= 'disable'

# %%
# running Sen2Cor for every image / применение Sen2Cor к каждому снимку
for path in paths:
    cmd = r'L2A_Process.bat "'+ path + '" '
    try:
        result = subprocess.check_output(cmd, env=my_env, shell=True)
        shutil.rmtree(path)
        print(path)
    except subprocess.CalledProcessError as e:
        print(e)

# %% [markdown]
# ### Applying superresolution algorythm
# ### Применение алгоритма суперразрешения

# %%
#importing python library for superresolution algorythm / импорт библиотеки, реализующей алгоритм суперразрешения
#https://github.com/simonreise/s2-superres

import sys
sys.path.insert(1, r'C:\Users\mosko\Downloads\s2-superres\src\s2_superres')
import s2_superres

# %%
out_dir = r'F:\Work\CorrProizv\superres\\'

#applying superresolution to every image / применяем алгоритм суперразрешения к каждому снимку
for path in paths:
    pref = Path(path).stem
    if (Path(out_dir + pref + '_superresolution.tif').is_file()):
        print('Pass: ' + path)
    else:
        s2_superres.Superresolution(input_dir = path, output_dir = out_dir, copy_original_bands = True).start()
        print('DONE: ' + path)
        print('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')

# %% [markdown]
# ### Cloud masking, errors fixing and reprojection
# ### Маскировка облаков, исправление технических ошибок и перепроецирование

# %%
for path in paths:
    #loading bands / загрузка всех каналов
    if os.path.isfile('F:\\Work\\CorrProizv\\projected\\' + path.split('\\')[4][:-5] + '\\B1.tif'):
        print('Skip', path)
    else:
        img = 'F:\\Work\\CorrProizv\\superres\\' + path.split('\\')[4][:-5] + '_superresolution.tif'
        with rio.open(img) as bands:
            img = bands.read()
            meta = bands.profile
            bounds = bands.bounds
            descs = bands.descriptions
            transform = bands.transform
        #masking zeros / маскировка нулей
        img = np.where(img == 0, 1, img)
        #masking 65555 pixels / маскировка значений 65555
        mask = np.where(img > 15000, 0, 1)
        for i in range(img.shape[0]):
            img[i] = rio.fill.fillnodata(img[i], mask[i], max_search_distance = 500)
        #masking clouds by Sentinel L1 mask / маскировка облаков при помощи всроенной маски Sentinel L1
        try:
            shape = glob(path + '\\GRANULE\\**\\QI_DATA\\MSK_CLOUDS_B00.gml')[0]
            with fiona.open(shape, "r") as shapefile:
                cloudmask = [feature["geometry"] for feature in shapefile]
            with MemoryFile() as memfile:
                with memfile.open(
                    driver='GTiff',
                    height=img.shape[1],
                    width=img.shape[2],
                    count=img.shape[0],
                    dtype=img.dtype,
                    compress = 'lzw',
                    crs=meta['crs'],
                    transform=transform
                ) as temp:
                    temp.write(img)
                    img, transform = rio.mask.mask(temp, cloudmask, invert = True, filled = True)
        except:
            pass
        #masking clouds by algorythm based on Scene Classification of L2 product and bands 1 and 9
        #маскировка облаков при помощи алгоритма, основанного на классификации снимка уровня 2 и каналов 1 и 9
        l1path = glob(path + r'\GRANULE\*\IMG_DATA\R20m\*SCL_20m.jp2')
        with rio.open(l1path[0]) as classification:
            cls = classification.read()
            clsmeta = classification.profile
        mask = np.empty_like(img[0])
        reproject(
            cls, mask,
            src_transform = clsmeta['transform'],
            dst_transform = meta['transform'],
            src_crs = clsmeta['crs'],
            dst_crs = meta['crs'],
            resampling = Resampling.nearest)
        for i in range(len(descs)):
            if 'B1 ' in descs[i]:
                band1 = i
        for i in range(len(descs)):
            if 'B9 ' in descs[i]:
                band9 = i
        clmask = np.where(((img[band1] >= 3200) & (img[band9] >= 6000) & (mask >= 7)), 1, 0)
        #delete 1px gaps in mask / удаление пробелов в 1 пиксел
        clmask = np.where((rio.fill.fillnodata(np.where(clmask == 1, 0, 1), np.where(clmask == 1, 0, 1), max_search_distance = 2)) == 1, 0, 1)
        #emerge mask / увеличение маски
        clmask = rio.fill.fillnodata(clmask, clmask, max_search_distance = 22)
        img = np.where(clmask > 0, 0, img)
        #masking nodata / маскировка
        img = np.where(mask == 0, 0, img)
        #reprojecting / перепроецирование
        if meta['crs'] != 'EPSG:32642':
            transform, width, height = calculate_default_transform(
                meta['crs'], 'EPSG:32642', meta['width'], meta['height'], *bounds)
            proj = np.zeros((img.shape[0], width, height), img.dtype)
            img, transform = reproject(
                source=img,
                destination=proj,
                src_transform=meta['transform'],
                src_crs=meta['crs'],
                dst_transform=transform,
                dst_crs='EPSG:32642',
                resampling=Resampling.nearest)
            img = proj
        #save / сохранение
        Path('F:\\Work\\CorrProizv\\projected\\' + path.split('\\')[4][:-5]).mkdir(parents=True, exist_ok=True)
        for i in range(img.shape[0]):
            pathres = 'F:\\Work\\CorrProizv\\projected\\' + path.split('\\')[4][:-5] + '\\' + descs[i].split(' ')[1] + '.tif'
            with rio.open(
                pathres,
                'w',
                driver='GTiff',
                height=img.shape[1],
                width=img.shape[2],
                count=1,
                dtype=img.dtype,
                compress = 'deflate',
                PREDICTOR = 2,
                ZLEVEL=9,
                crs='EPSG:32642',
                transform=transform,
                nodata = 0
            ) as outfile:
                outfile.write(img[i],1)
        print(path)
# Out:
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20170731T060631_N9999_R134_T44VMN_20210915T184413.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20170731T060631_N9999_R134_T44VNQ_20210916T052032.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20170731T060631_N9999_R134_T44VPQ_20210915T081105.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20180630T072621_N9999_R049_T41VML_20210916T045925.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20180723T055641_N9999_R091_T44VNP_20210915T192826.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20180826T071621_N9999_R006_T41VMK_20210915T093843.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190701T060641_N9999_R134_T44VMN_20210915T070556.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190701T060641_N9999_R134_T44VMR_20210915T195148.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190715T054641_N9999_R048_T44VPN_20210915T042924.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190721T060641_N9999_R134_T43VFJ_20210915T012154.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190721T060641_N9999_R134_T44VLN_20210915T182127.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190721T060641_N9999_R134_T44VLP_20210915T005950.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190721T060641_N9999_R134_T44VLQ_20210915T073007.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190721T060641_N9999_R134_T44VNQ_20210915T032204.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190721T060641_N9999_R134_T45VUK_20210915T024042.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190725T072621_N9999_R049_T40VFR_20210914T225005.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190725T072621_N9999_R049_T40WFS_20210915T003945.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190725T072621_N9999_R049_T40WFT_20210915T020246.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190725T072621_N9999_R049_T41VLL_20210914T231151.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190725T072621_N9999_R049_T41VMJ_20210916T043910.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190725T072621_N9999_R049_T41VML_20210915T014030.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190725T072621_N9999_R049_T41WMM_20210915T001800.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190725T072621_N9999_R049_T41WMN_20210915T021927.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190813T061631_N9999_R034_T43VDG_20210914T212730.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190813T061631_N9999_R034_T43VFH_20210914T220628.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190813T061631_N9999_R034_T44VLN_20210914T222817.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190813T061631_N9999_R034_T44VLP_20210914T204329.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190813T061631_N9999_R034_T44VMQ_20210914T233339.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190814T054641_N9999_R048_T44VPP_20210915T074756.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190814T054641_N9999_R048_T45VUJ_20210914T214401.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190818T070621_N9999_R106_T41VPL_20210914T174935.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190820T074611_N9999_R135_T41WMN_20210914T132020.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190821T071621_N9999_R006_T41VNJ_20210914T153753.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190821T071621_N9999_R006_T41VNL_20210914T125849.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190821T071621_N9999_R006_T41VPK_20210914T143947.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190821T071621_N9999_R006_T41WNM_20210914T141333.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190821T071621_N9999_R006_T41WPM_20210914T191419.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190821T071621_N9999_R006_T42VUR_20210914T123742.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190822T064631_N9999_R020_T42VWM_20210915T140446.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190822T064631_N9999_R020_T42VWP_20210914T115544.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190822T064631_N9999_R020_T42VXN_20210915T142700.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190822T064631_N9999_R020_T42VXP_20210915T175658.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190822T064631_N9999_R020_T42VXQ_20210915T153835.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190822T064631_N9999_R020_T42VXR_20210915T160235.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190823T061631_N9999_R034_T43VFH_20210914T102732.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190823T061631_N9999_R034_T43VFJ_20210914T111038.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20190823T061631_N9999_R034_T44VLN_20210914T113238.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200605T060641_N9999_R134_T44VMQ_20210914T100459.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200609T054641_N9999_R048_T44VPQ_20210914T082206.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200609T054641_N9999_R048_T45VVJ_20210914T084258.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200610T065631_N9999_R063_T42VUP_20210914T073838.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200611T062631_N9999_R077_T43VEJ_20210915T164842.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200611T062631_N9999_R077_T43VFJ_20210914T133734.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200628T061641_N9999_R034_T44VMQ_20210914T162133.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200703T070631_N9999_R106_T41VNK_20210915T053945.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200703T070631_N9999_R106_T42VUP_20210914T071651.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200708T061631_N9999_R034_T43VFJ_20210914T065417.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200709T072621_N9999_R049_T40VFQ_20210914T063312.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200709T072621_N9999_R049_T41VLJ_20210914T050403.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200710T065631_N9999_R063_T41VNF_20210914T034243.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200710T065631_N9999_R063_T41VNG_20210914T032628.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200710T065631_N9999_R063_T42VUM_20210914T012244.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200710T065631_N9999_R063_T42VVM_20210915T131934.SAFE
# F:\Work\CorrProizv\Imagery\S2A_MSIL2A_20200710T065631_N9999_R063_T42V

#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200617T055639_N9999_R091_T44VMN_20210914T121732',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200715T065629_N9999_R063_T41VPF_20210913T181456',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200715T065629_N9999_R063_T41VPG_20210913T194132',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VUL_20210913T202449',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VVP_20210913T183538',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VVQ_20210913T175303',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VWQ_20210913T200226',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VXR_20210913T185752',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200716T062629_N9999_R077_T43VCF_20210915T134227',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200716T062629_N9999_R077_T43VDF_20210913T165044',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200716T062629_N9999_R077_T43VEF_20210913T173207',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200808T063629_N9999_R120_T42VWN_20210913T105049',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200808T063629_N9999_R120_T43VDK_20210913T094611',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200814T065629_N9999_R063_T42VVQ_20210913T075830']

# %% [markdown]
# ###### Sorting images by cloud cover - less cloudy on top
# ###### Сортировка снимков по облачности - наименее облачные сверху

# %%
#getting number of nodata pixels for each image / количество значений "нет данных" для каждого снимка
zeros = []
for path in spaths:
    path = path + '\\B1.tif'
    with rio.open(path) as bnd:
        img = bnd.read(1)
    try:
        zeros.append(np.count_nonzero(img==0))
    except:
        zeros.append(0)

# %%
#sorting images by number of nodata pixels / сортировка снимков по количеству пикселов "нет даннных"
zerosdict = dict(zip(spaths, zeros))
sortedzeros = dict(sorted(zerosdict.items(), key=lambda item: item[1], reverse = True))
order = list(sortedzeros.keys())
order
# Out:
# ['F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190721T060641_N9999_R134_T44VLQ_20210915T073007',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190721T060641_N9999_R134_T45VUK_20210915T024042',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190725T072621_N9999_R049_T40WFT_20210915T020246',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T41VNG_20210914T032628',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200608T070629_N9999_R106_T41VMH_20210914T090442',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200617T055639_N9999_R091_T44VMN_20210914T121732',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190820T074611_N9999_R135_T41WMN_20210914T132020',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20190819T072619_N9999_R049_T40WFS_20210914T181115',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190813T061631_N9999_R034_T43VDG_20210914T212730',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20170731T060631_N9999_R134_T44VPQ_20210915T081105',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190721T060641_N9999_R134_T44VLP_20210915T005950',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190721T060641_N9999_R134_T43VFJ_20210915T012154',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190725T072621_N9999_R049_T40WFS_20210915T003945',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200609T054641_N9999_R048_T44VPQ_20210914T082206',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20190815T074619_N9999_R135_T40WFS_20210914T202143',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200607T055639_N9999_R091_T45VUH_20210914T092151',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T42VXQ_20210914T020454',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20190819T072619_N9999_R049_T41VNK_20210914T164557',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200805T053651_N9999_R005_T45VVH_20210913T121305',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200609T054641_N9999_R048_T45VVJ_20210914T084258',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190814T054641_N9999_R048_T45VUJ_20210914T214401',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200808T054641_N9999_R048_T44VPP_20210913T100855',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200628T061641_N9999_R034_T44VMQ_20210914T162133',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190725T072621_N9999_R049_T40VFR_20210914T225005',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20190829T072619_N9999_R049_T40VFR_20210914T104948',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T41VNF_20210914T034243',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190823T061631_N9999_R034_T44VLN_20210914T113238',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200709T072621_N9999_R049_T40VFQ_20210914T063312',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190721T060641_N9999_R134_T44VNQ_20210915T032204',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20190819T072619_N9999_R049_T40VFQ_20210914T160028',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190701T060641_N9999_R134_T44VMR_20210915T195148',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200610T060639_N9999_R134_T44VNQ_20210914T075955',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20180724T061629_N9999_R034_T44VMP_20210915T190617',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200714T063631_N9999_R120_T43VDG_20210913T231520',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190701T060641_N9999_R134_T44VMN_20210915T070556',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200605T060641_N9999_R134_T44VMQ_20210914T100459',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190721T060641_N9999_R134_T44VLN_20210915T182127',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20180827T073719_N9999_R092_T40WFT_20210915T064455',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20190703T055649_N9999_R091_T44VNP_20210915T045336',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190814T054641_N9999_R048_T44VPP_20210915T074756',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200703T070631_N9999_R106_T41VNK_20210915T053945',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20180827T073719_N9999_R092_T40WFS_20210915T085334',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20180723T055641_N9999_R091_T44VNP_20210915T192826',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200716T062629_N9999_R077_T43VEF_20210913T173207',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20170731T060631_N9999_R134_T44VNQ_20210916T052032',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190813T061631_N9999_R034_T44VMQ_20210914T233339',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190715T054641_N9999_R048_T44VPN_20210915T042924',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200804T060641_N9999_R134_T44VMP_20210913T123421',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190813T061631_N9999_R034_T44VLP_20210914T204329',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20190802T055649_N9999_R091_T44VNN_20210914T235559',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20170731T060631_N9999_R134_T44VMN_20210915T184413',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190813T061631_N9999_R034_

#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200806T064631_N9999_R020_T42VWM_20210913T131744',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200806T064631_N9999_R020_T42VVL_20210913T133800',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200703T070631_N9999_R106_T42VUP_20210914T071651',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200714T063631_N9999_R120_T42VXQ_20210913T191848',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200610T065631_N9999_R063_T42VUP_20210914T073838',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190822T064631_N9999_R020_T42VXN_20210915T142700',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VVP_20210913T183538',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20190820T065629_N9999_R063_T42VUM_20210915T123502',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200605T065629_N9999_R063_T42VUP_20210915T112829',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T42VWP_20210914T042245',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190822T064631_N9999_R020_T42VWP_20210914T115544',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200717T064631_N9999_R020_T42VVM_20210913T160650',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VWQ_20210913T200226',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20190714T070629_N9999_R106_T42VUP_20210915T034512',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190822T064631_N9999_R020_T42VWM_20210915T140446',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190822T064631_N9999_R020_T42VXR_20210915T160235',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200714T063631_N9999_R120_T42VXM_20210914T004022',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190822T064631_N9999_R020_T42VXP_20210915T175658',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190822T064631_N9999_R020_T42VXQ_20210915T153835',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200714T063631_N9999_R120_T42VXP_20210913T212857',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200714T063631_N9999_R120_T42VXN_20210913T221031',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T42WWS_20210914T010059',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T42VWQ_20210914T054847',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T42VVN_20210914T040112',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T42VVR_20210914T030501',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T42VVP_20210914T061220',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T42VVM_20210915T131934',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T42VVQ_20210914T024337',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200710T065631_N9999_R063_T42VWR_20210914T052551',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20190714T070629_N9999_R106_T42VUN_20210915T051743',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20200717T064631_N9999_R020_T42VVL_20210915T125706',
#  'F:\\Work\\CorrProizv\\Projected\\S2A_MSIL2A_20190821T071621_N9999_R006_T42VUR_20210914T123742',
#  'F:\\Work\\CorrProizv\\Projected\\S2B_MSIL2A_20200715T065629_N9999_R063_T42VUL_20210913T202449']

# %%
#merging images into one mosaic / объединение снимков
bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12']
for band in bands:
    #reading n-th band from every image / чтение n-ного канала каждого из снимков
    ordfiles = []
    for img in order:
        img = img + '\\' + band + '.tif'
        ordfiles.append(img)
    files = []
    for path in ordfiles:
        pathfile = rio.open(path)
        files.append(pathfile)
    #merging / объединение
    final, final_trans = rio.merge.merge(files,method = 'last')
    print('merge done')
    #filling the gaps (if exist) / заполнение пустот (если они есть)
    final = rio.fill.fillnodata(final, final, max_search_distance=250)
    print('fill done')
    #clipping the mosaic to the extent of KhMAO / обрезка мозаики по границе ХМАО
    files = None
    memfile = None
    temp = None
    with fiona.open("E:\\Work\\CorrProizv\\clipper.gpkg", "r") as shapefile:
        shape = [feature["geometry"] for feature in shapefile]
    with MemoryFile() as memfile:
        with memfile.open(
            driver='GTiff',
            height=final.shape[1],
            width=final.shape[2],
            count=final.shape[0],
            dtype=final.dtype,
            compress = 'lzw',
            crs='EPSG:32642',
            transform=final_trans,
            BIGTIFF='YES',
            nodata = 0
        ) as temp:
            temp.write(final)
            final, final_trans = rio.mask.mask(temp, shape,crop=True, filled=True)
    print('clipping done')
    #saving / сохранение
    with rio.open(
        'F:\\Work\\CorrProizv\\final_noadj\\'+ band + '.tif',
        'w',
        driver='GTiff',
        height=final.shape[1],
        width=final.shape[2],
        count=1,
        dtype=final.dtype,
        compress = 'lzw',
        crs='EPSG:32642',
        transform=final_trans,
        BIGTIFF='YES',
        nodata = 0
    ) as outfile:
        outfile.write(final)
    print(band)
# Out:
# merge done

# %% [markdown]
# #### Sentinel-2 processing tools from this notebook are now avaliable in a Python library named [Remote Sensing Processor](https://github.com/simonreise/remote-sensing-processor)
# #### Инструменты предобработки Sentinel-2, использованные в этом блокноте доступны в библиотеке Python [Remote Sensing Processor](https://github.com/simonreise/remote-sensing-processor)
